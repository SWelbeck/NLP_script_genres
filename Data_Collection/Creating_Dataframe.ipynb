# %%
import pandas as pd
import numpy as np
import os
import glob
import errno

# %%
# !pwd
# Out:
# /Users/sandrawelbeck/Desktop/Flatiron_DS_Bootcamp/Capstone_Flatiron/NLP_script_genres/Data_Collection

# %%
data_path = "../data/scraping/texts/"
       
all_files = os.listdir("../data/scraping/texts/")   # imagine you're one directory above test dir

# %%
files = glob.glob("../data/scraping/texts/*.txt")

# %%
for name in files: 
    try: 
        with open(name) as f: 
            f.read() # do what you want 
    except IOError as exc: 
        if exc.errno != errno.EISDIR: 
            raise

# %%
for i in txt_files:
    with open(i, 'r') as fd:
        files = fd.read()

# %%
files
# Out:
# '\n\t\t\n\n                          "TERMINATOR 2: JUDGEMENT DAY"\n\n                                 a Screenplay\n\n                                      by\n\n                                 James Cameron\n\n                                      and\n\n                                 William Wisher\n\n\n\n\n        Revised final shooting script\n\n\n\n1       EXT. CITY STREET - DAY\n\n        Downtown L.A.  Noon on a hot summer day.  On an EXTREME LONG LENS the\n        lunchtime crowd stacks up into a wall of humanity.  In SLOW MOTION\n        they move in herds among the glittering rows of cars jammed bumper to\n        bumper.  Heat ripples distort the torrent of faces.  The image is\n        surreal, dreamy... and like a dream it begins very slowly to\n\n                                                DISSOLVE TO:\n\n2       EXT. CITY RUINS - NIGHT\n\n        Same spot as the last shot, but now it is a landscape in Hell.  The\n        cars are stopped in rusted rows, still 
# ...

# %%
f = open('../data/scraping/texts/Jacket.txt', 'r')

# %%
jackie = f.readlines()

# %%
jackie
# Out:
# ['\n',
#  '\n',
#  ' \n',
#  '                                       THE JACKET              \n',
#  '\n',
#  '               \n',
#  '                                       Written by \n',
#  '\n',
#  '                                     Massy Tadjedin\n',
#  '\n',
#  '               \n',
#  '                                Based on a screenplay by \n',
#  '\n',
#  '                                       Marc Rocco\n',
#  '\n',
#  '\n',
#  '               \n',
#  '                                                             April 15, 2003\n',
#  '\n',
#  '\n',
#  '\n',
#  '               \n',
#  '               A pure white screen. Idyllic stillness. All of it looking and\n',
#  '               feeling like the heavens are supposed to.\n',
#  '\n',
#  '               \n',
#  '               After some seconds of calm, water seems to mist the screen\n',
#  '               and the slight shifts to the left and then the right suggest\n',
# ...

# %%
for i in jackie:
    print(i)
# Out:
#
#
#                                        THE JACKET
#
#
#
#
#
#                                        Written by
#
#
#
#                                      Massy Tadjedin
#
#
#
#
#
#                                 Based on a screenplay by
#
#
#
#                                        Marc Rocco
#
#
#
#
#
#
#
#                                                              April 15, 2003
#
#
#
#
#
#
#
#
#
#                A pure white screen. Idyllic stillness. All of it looking and
#
#                feeling like the heavens are supposed to.
#
#
#
#
#
#                After some seconds of calm, water seems to mist the screen
#
#                and the slight shifts to the left and then the right suggest
#
#                this is a man's P.O.V. Then, suddenly, the white screen is
#
#                tugged and we see it was a sheet covering a presumably dead
#
#                man.
#
#
#
#
#
#
#
#                                      WILLIAM STARKS (V.O.)
#
# ...

# %%
# data = pd.read_csv()
